# %%
import pandas as pd
import numpy as np
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1001,1032):
    temp = pd.read_csv('../bus_data/arriv_records/arriv_record_train2017{}.csv'.format(str(i)),usecols=['O_LINENO','O_TERMINALNO','O_TIME','O_LONGITUDE','O_LATITUDE','O_UP','O_NEXTSTATIONNO'])
    temp = temp[(temp.O_LINENO == 47) & (temp.O_UP == 1)]
    df = df.append(temp,ignore_index=True)
del temp
df
# Out:
#      O_LINENO  O_TERMINALNO    O_TIME  O_LONGITUDE  O_LATITUDE  O_UP  \
# 0          47        962345  09:41:00      117.136     39.1764     1
# 1          47        962345  14:45:16      117.136     39.1765     1
# 2          47        962353  14:58:36        0.000      0.0000     1
# 3          47        962353  15:04:35      117.142     39.1494     1
# 4          47        962353  15:06:34        0.000      0.0000     1
# 5          47        904340  12:59:49      117.136     39.1767     1
# 6          47        962342  16:55:30        0.000      0.0000     1
# 7          47        962342  16:56:50      117.151     39.1737     1
# 8          47        962342  17:00:09      117.147     39.1682     1
# 9          47        962345  14:08:41        0.000      0.0000     1
# 10         47        962345  14:09:22        0.000      0.0000     1
# 11         47        962345  14:10:32        0.000      0.0000     1
# 12         47        962352  07:34:34      117.136     39.1766     1
# ...

# %%
df[df.O_NEXTSTATIONNO == 42]
# Out:
#      O_LINENO  O_TERMINALNO    O_TIME  O_LONGITUDE  O_LATITUDE  O_UP  \
# 12         47        962352  07:34:34      117.136     39.1766     1
# 74         47        963852  10:13:23      117.136     39.1770     1
# 75         47        962346  10:38:08      117.136     39.1766     1
# 136        47        962346  20:34:22      118.162     38.8991     1
#
#      O_NEXTSTATIONNO
# 12                42
# 74                42
# 75                42
# 136               42

# %%
df.to_csv('../bus_data/to_API/47_1.csv',index=False)

# %%
# Out:
#        O_LINENO  O_TERMINALNO    O_TIME  O_LONGITUDE  O_LATITUDE  O_UP  \
# 59816        47        962345  09:41:00      117.136     39.1764     1
# 59902        47        962345  14:45:16      117.136     39.1765     1
#
#        O_NEXTSTATIONNO
# 59816                2
# 59902                2

# %%
temp
