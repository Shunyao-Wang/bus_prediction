# %%
# -*- coding: utf-8 -*-
# Python3.5
import requests  # 导入requests
from bs4 import BeautifulSoup  # 导入bs4中的BeautifulSoup
import os
import pandas as pd
import numpy as np

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0'}
all_url = 'http://tianjin.8684.cn'  # 开始的URL地址
start_html = requests.get(all_url, headers=headers)
# print (start_html.text)
Soup = BeautifulSoup(start_html.text, 'lxml')
all_a = Soup.find_all('div', class_='bus_layer_r')[2].find_all('a')
Network_list = pd.DataFrame(
    columns=['line_no', 'line_up', 'station_num', 'station_0', 'name_0'])
station = []  # list保存唯一站点名和编号
station_id = -1  # 唯一编号
temp = 1

# %%
for a in all_a:  # A-Z
    href = a['href']  # 取出a标签的href 属性
    html = all_url + href
    second_html = requests.get(html, headers=headers)
    # print (second_html.text)
    Soup2 = BeautifulSoup(second_html.text, 'lxml')
    all_a2 = Soup2.find('div', class_='cc_content').find_all(
        'div')[-1].find_all('a')  # 既有id又有class的div不知道为啥取不出来，只好迂回取了
    for a2 in all_a2:
        # title1 = a2.get_text()  # 取出a1标签的文本
        href1 = a2['href']  # 取出a标签的href 属性
        station_name = a2.get_text()
        station.append(station_name)
        station_id += 1
        # print (title1,href1)
        html_bus = all_url + href1
        thrid_html = requests.get(html_bus, headers=headers)
        Soup3 = BeautifulSoup(thrid_html.text, 'lxml')
        #bus_name = Soup3.find('div', class_='bus_i_t1').find('h1').get_text()
        # print (bus_name,bus_type,bus_time,bus_cost,bus_company,bus_update)

        ''' 获取线路站点位置  '''
        allline = Soup3.find_all('a', class_='bus_i_span')
        for line in allline:
            line_name = line.get_text()  # '5路'
            href2 = line['href']  # 5路的url 'x_b1c60aa8'
            html_line = all_url + href2
            fourth_html = requests.get(html_line, headers=headers)
            Soup4 = BeautifulSoup(fourth_html.text, 'lxml')

            all_line = Soup4.find_all('div', class_='bus_line_top')  # 上下行
            all_site = Soup4.find_all('div', class_='bus_line_site')

            for line_up in range(len(all_line)):
                line_x = all_line[line_up].find('div', class_='bus_line_txt').get_text()[
                    :-9]+all_line[line_up].find_all('span')[-1].get_text()
                sites_x = all_site[line_up].find_all('a')
                station_num = len(sites_x)
                if station_num > (Network_list.columns.size-3)/2:
                    while temp != station_num:
                        Network_list['station_{}'.format(temp)] = None
                        Network_list['name_{}'.format(temp)] = None
                        temp += 1
                i = 0
                for site_x in sites_x:
                    if str(site_x).find(href1) != -1:
                        if len(Network_list[(Network_list.line_no == line_name) & (Network_list.line_up == line_up)]) != 0:
                            index = Network_list[(Network_list.line_no == line_name) & (
                                Network_list.line_up == line_up)].index[0]
                            Network_list.loc[index, 'station_{}'.format(
                                i)] = station_id
                            Network_list.loc[index, 'name_{}'.format(
                                i)] = site_x.get_text()

                        else:
                            sites_x_list = dict()  # 字典是为了往Dataframe按行存
                            sites_x_list.update(
                                {'station_{}'.format(i): station_id, 'name_{}'.format(i): site_x.get_text()})
                            information = {'line_no': line_name,
                                           'line_up': line_up, 'station_num': station_num}
                            information.update(sites_x_list)
                            Network_list = Network_list.append(
                                information, ignore_index=True)
                    i += 1
        if station_id%10 == 0:
            print('compulate {}'.format(station_id))
print('crawler success!')
# Out:
# compulate 0
# compulate 10
# compulate 20
# compulate 30
# compulate 40
# compulate 50
# compulate 60
# compulate 70
# compulate 80
# compulate 90
# compulate 100
# compulate 110
# compulate 120
# compulate 130
# compulate 140
# compulate 150
# compulate 160
# compulate 170
# compulate 180
# compulate 190
# compulate 200
# compulate 210
# compulate 220
# compulate 230
# compulate 240
# compulate 250
# compulate 260
# compulate 270
# compulate 280
# compulate 290
# compulate 300
# compulate 310
# compulate 320
# compulate 330
# compulate 340
# compulate 350
# compulate 360
# compulate 370
# compulate 380
# compulate 390
# compulate 400
# compulate 410
# compulate 420
# compulate 430
# compulate 440
# compulate 450
# compulate 460
# compulate 470
# compulate 480
# compulate 490
# compulate 500
# compulate 510
# compulate 520
# compulate 530
# compulate 540
# compulate 550
# compulate 560
# compulate 570
# compulate 580
# compulate 590
# compulate 600
# compulate 610
# compulate 620
# compulate 630
# compulate 640
# compulate 650
# compulate 660
# compulate 670
# compulate 680
# compulate 690
# compulate 700
# compulate 710
# compulate 720
# compulate 730
# compulate 740
# compulate 750
# compulate 760
# compulate 770
# compulate 780
# compulate 790
# compulate 800
# compulate 810
# compulate 820
# compulate 830
# compulate 840
# compulate 850
# compulate 860
# compulate 870
# compulate 880
# compulate 890
# compulate 900
# compulate 910
# compulate 920
# compulate 930
# compulate 940
# compulate 950
# compulate 960
# compulate 970
# compulate 980
# compulate 990
# compulate 1000
# compulate 1010
# compulate 1020
# compulate 1030
# compulate 1040
# compulate 1050
# compulate 1060
# compulate 1070
# compulate 1080
# compulate 1090
# compulate 1100
# compulate 1110
# compulate 1120
# compulate 1130
# compulate 1140
# compulate 1150
# compulate 1160
# compulate 1170
# compulate 1180
# compulate 1190
# compulate 1200
# compulate 1210
# compulate 1220
# compulate 1230
# compulate 1240
# compulate 1250
# compulate 1260
# compulate 1270
# compulate 1280
# compulate 1290
# compulate 1300
# compulate 1310
# compulate 1320
# compulate 1330
# compulate 1340
# compulate 1350
# compulate 1360
# compulate 1370
# compulate 1380
# compulate 1390
# compulate 1400
# compulate 1410
# compulate 1420
# compulate 1430
# compulate 1440
# compulate 1450
# compulate 1460
# compulate 1470
# compulate 1480
# compulate 1490
# compulate 1500
# compulate 1510
# compulate 1520
# compulate 1530
# compulate 1540
# compulate 1550
# compulate 1560
# compulate 1570
# compulate 1580
# compulate 1590
# compulate 1600
# compulate 1610
# compulate 1620
# compulate 1630
# compulate 1640
# compulate 1650
# compulate 1660
# compulate 1670
# compulate 1680
# compulate 1690
# compulate 1700
# compulate 1710
# compulate 1720
# compulate 1730
# compulate 1740
# compulate 1750
# compulate 1760
# compulate 1770
# compulate 1780
# compulate 1790
# compulate 1800
# compulate 1810
# compulate 1820
# compulate 1830
# compulate 1840
# compulate 1850
# compulate 1860
# compulate 1870
# compulate 1880
# compulate 1890
# compulate 1900
# compulate 1910
# compulate 1920
# compulate 1930
# compulate 1940
# compulate 1950
# compulate 1960
# compulate 1970
# compulate 1980
# compulate 1990
# compulate 2000
# compulate 2010
# compulate 2020
# compulate 2030
# compulate 2040
# compulate 2050
# compulate 2060
# compulate 2070
# compulate 2080
# compulate 2090
# compulate 2100
# compulate 2110
# compulate 2120
# compulate 2130
# compulate 2140
# compulate 2150
# compulate 2160
# compulate 2170
# compulate 2180
# compulate 2190
# compulate 2200
# compulate 2210
# compulate 2220
# compulate 2230
# compulate 2240
# compulate 2250
# compulate 2260
# compulate 2270
# compulate 2280
# compulate 2290
# compulate 2300
# compulate 2310
# compulate 2320
# compulate 2330
# compulate 2340
# compulate 2350
# compulate 2360
# compulate 2370
# compulate 2380
# compulate 2390
# compulate 2400
# compulate 2410
# compulate 2420
# compulate 2430
# compulate 2440
# compulate 2450
# compulate 2460
# compulate 2470
# compulate 2480
# compulate 2490
# compulate 2500
# compulate 2510
# compulate 2520
# compulate 2530
# compulate 2540
# compulate 2550
# compulate 2560
# compulate 2570
# compulate 2580
# compulate 2590
# compulate 2600
# compulate 2610
# compulate 2620
# compulate 2630
# compulate 2640
# compulate 2650
# compulate 2660
# compulate 2670
# compulate 2680
# compulate 2690
# compulate 2700
# compulate 2710
# compulate 2720
# compulate 2730
# compulate 2740
# compulate 2750
# compulate 2760
# compulate 2770
# compulate 2780
# compulate 2790
# compulate 2800
# compulate 2810
# compulate 2820
# compulate 2830
# compulate 2840
# compulate 2850
# compulate 2860
# compulate 2870
# compulate 2880
# compulate 2890
# compulate 2900
# compulate 2910
# compulate 2920
# compulate 2930
# compulate 2940
# compulate 2950
# compulate 2960
# compulate 2970
# compulate 2980
# compulate 2990
# compulate 3000
# compulate 3010
# compulate 3020
# compulate 3030
# compulate 3040
# compulate 3050
# compulate 3060
# compulate 3070
# compulate 3080
# compulate 3090
# compulate 3100
# compulate 3110
# compulate 3120
# compulate 3130
# compulate 3140
# compulate 3150
# compulate 3160
# compulate 3170
# compulate 3180
# compulate 3190
# compulate 3200
# compulate 3210
# compulate 3220
# compulate 3230
# compulate 3240
# compulate 3250
# compulate 3260
# compulate 3270
# compulate 3280
# compulate 3290
# compulate 3300
# compulate 3310
# compulate 3320
# compulate 3330
# compulate 3340
# compulate 3350
# compulate 3360
# compulate 3370
# compulate 3380
# compulate 3390
# compulate 3400
# compulate 3410
# compulate 3420
# compulate 3430
# compulate 3440
# compulate 3450
# compulate 3460
# compulate 3470
# compulate 3480
# compulate 3490
# compulate 3500
# compulate 3510
# compulate 3520
# compulate 3530
# compulate 3540
# compulate 3550
# compulate 3560
# compulate 3570
# compulate 3580
# compulate 3590
# compulate 3600
# compulate 3610
# compulate 3620
# compulate 3630
# compulate 3640
# compulate 3650
# compulate 3660
# compulate 3670
# compulate 3680
# compulate 3690
# compulate 3700
# compulate 3710
# compulate 3720
# compulate 3730
# compulate 3740
# compulate 3750
# compulate 3760
# compulate 3770
# compulate 3780
# compulate 3790
# compulate 3800
# compulate 3810
# compulate 3820
# compulate 3830
# compulate 3840
# compulate 3850
# compulate 3860
# compulate 3870
# compulate 3880
# compulate 3890
# compulate 3900
# compulate 3910
# compulate 3920
# compulate 3930
# compulate 3940
# compulate 3950
# compulate 3960
# compulate 3970
# compulate 3980
# compulate 3990
# compulate 4000
# compulate 4010
# compulate 4020
# compulate 4030
# compulate 4040
# compulate 4050
# compulate 4060
# compulate 4070
# compulate 4080
# compulate 4090
# compulate 4100
# compulate 4110
# compulate 4120
# compulate 4130
# compulate 4140
# compulate 4150
# compulate 4160
# compulate 4170
# compulate 4180
# compulate 4190
# compulate 4200
# compulate 4210
# compulate 4220
# compulate 4230
# compulate 4240
# compulate 4250
# compulate 4260
# compulate 4270
# compulate 4280
# compulate 4290
# compulate 4300
# compulate 4310
# compulate 4320
# compulate 4330
# compulate 4340
# compulate 4350
# compulate 4360
# compulate 4370
# compulate 4380
# compulate 4390
# compulate 4400
# compulate 4410
# compulate 4420
# compulate 4430
# compulate 4440
# compulate 4450
# compulate 4460
# compulate 4470
# compulate 4480
# compulate 4490
# compulate 4500
# compulate 4510
# compulate 4520
# compulate 4530
# compulate 4540
# compulate 4550
# compulate 4560
# compulate 4570
# compulate 4580
# compulate 4590
# compulate 4600
# compulate 4610
# compulate 4620
# compulate 4630
# compulate 4640
# compulate 4650
# compulate 4660
# compulate 4670
# compulate 4680
# compulate 4690
# compulate 4700
# compulate 4710
# compulate 4720
# compulate 4730
# compulate 4740
# compulate 4750
# compulate 4760
# compulate 4770
# compulate 4780
# compulate 4790
# compulate 4800
# compulate 4810
# compulate 4820
# compulate 4830
# compulate 4840
# compulate 4850
# compulate 4860
# compulate 4870
# compulate 4880
# compulate 4890
# compulate 4900
# compulate 4910
# compulate 4920
# compulate 4930
# compulate 4940
# compulate 4950
# compulate 4960
# compulate 4970
# compulate 4980
# compulate 4990
# compulate 5000
# compulate 5010
# compulate 5020
# compulate 5030
# compulate 5040
# compulate 5050
# compulate 5060
# compulate 5070
# compulate 5080
# compulate 5090
# compulate 5100
# compulate 5110
# compulate 5120
# compulate 5130
# compulate 5140
# compulate 5150
# compulate 5160
# compulate 5170
# compulate 5180
# compulate 5190
# compulate 5200
# compulate 5210
# compulate 5220
# compulate 5230
# compulate 5240
# compulate 5250
# compulate 5260
# compulate 5270
# compulate 5280
# compulate 5290
# compulate 5300
# compulate 5310
# compulate 5320
# compulate 5330
# compulate 5340
# compulate 5350
# compulate 5360
# compulate 5370
# compulate 5380
# compulate 5390
# compulate 5400
# compulate 5410
# compulate 5420
# compulate 5430
# compulate 5440
# compulate 5450
# compulate 5460
# compulate 5470
# compulate 5480
# compulate 5490
# compulate 5500
# compulate 5510
# compulate 5520
# compulate 5530
# compulate 5540
# compulate 5550
# compulate 5560
# compulate 5570
# compulate 5580
# compulate 5590
# compulate 5600
# compulate 5610
# compulate 5620
# compulate 5630
# compulate 5640
# compulate 5650
# compulate 5660
# compulate 5670
# compulate 5680
# compulate 5690
# compulate 5700
# compulate 5710
# compulate 5720
# compulate 5730
# compulate 5740
# compulate 5750
# compulate 5760
# compulate 5770
# compulate 5780
# compulate 5790
# compulate 5800
# compulate 5810
# compulate 5820
# compulate 5830
# compulate 5840
# compulate 5850
# compulate 5860
# compulate 5870
# compulate 5880
# compulate 5890
# compulate 5900
# compulate 5910
# compulate 5920
# compulate 5930
# compulate 5940
# compulate 5950
# compulate 5960
# compulate 5970
# compulate 5980
# compulate 5990
# compulate 6000
# compulate 6010
# compulate 6020
# compulate 6030
# compulate 6040
# compulate 6050
# crawler success!

# %%
Se = pd.Series(station)
Se
# Out:
# 0           247社区
# 1           奥克斯电气
# 2             奥兰里
# 3         奥林匹克博物馆
# 4            奥林花园
# 5             安乐村
# 6            安光小学
# 7             安光村
# 8           安光油墨厂
# 9             安太里
# 10            安定里
# 11            安泽里
# 12           安津医院
# 13           安裕新村
# 14            安达桥
# 15            安阳道
# 16             敖北
# 17           敖嘴村口
# 18             敖西
# 19           爱国东里
# 20           爱国北里
# 21            爱国里
# 22            爱营里
# 23            艾林庄
# 24            艾蒲庄
# 25           阿尔卑斯
# 26           鞍山西道
# 27            鞍山道
# 28          BBA公司
# 29           五号堤路
#           ...
# 6029          赵庄南
# 6030          赵庄子
# 6031         赵庄子村
# 6032           赵本
# 6033          赵沽里
# 6034          赵温村
# 6035        赵翰林庄村
# 6036         赵苑小区
# 6037          赵连庄
# 6038       辰兴路佳宁道
# 6039         造甲中学
# 6040      造甲国道服务站
# 6041        造甲工业区
# 6042        造甲邮政所
# 6043        造甲镇政府
# 6044         造纸宿舍
# 6045    造纸宿舍(张贵庄)
# 6046          郑家套
# 6047          郑家楼
# 6048          郑州道
# 6049          郑庄子
# 6050     郑庄子[西青区]
# 6051         郑庄子村
# 6052           重工
# 6053        重阳里南门
# 6054         鑫银大厦
# 6055         钻井公司
# 6056          钻井路
# 6057     镇政府[静海镇]
# 6058          震新村
# Length: 6059, dtype: object

# %%
Network_list
# Out:
#         line_no line_up station_num station_0                 name_0  \
# 0          412路       0          16       199                  宝坻客运站
# 1          412路       1          16      2079                    貉子沽
# 2          591路       0          17      3160                  农产品市场
# 3          591路       1          17       198                   宝坻四中
# 4          562路       0          38      1574                   高新公寓
# 5          562路       1          38      4864                 徐官屯工业区
# 6           35路       0          26      2696         丽苑小区站(丽苑小区公交站)
# 7           35路       1          26      3891                 水上公园东门
# 8          327路       0          14      2171                井冈山路公交站
# 9          327路       1          14      5232                  公交四公司
# 10         353路       0          20      4486            文江美庭苑(文江家园)
# 11         353路       1          22       805                  东风立交桥
# 12         130路       0          44      1612                会展中心公交站
# 13         130路       1          45       975        大港公交站(大港大学城公交站)
# 14         524路       0          46      1612                会展中心公交站
# 15         524路       1          46      5496         油田客运总站(三号院客运站)
# 16     524路(快线)       0          32      1596            高铁于家堡站(终点站)
# 17     524路(快线)       1          32      5496         油田客运总站(三号院客运站)
# 18         104路       0          53       287                  滨海大学城
# 19         104路       1          52      5177              西部新城公交首末站
# 20         617路       0          27      4100                  塘沽十三中
# 21         617路       1          27      3969                石油新村终点站
# 22         816路       0          34      4951             新港三号路(海防里)
# 23         816路       1          35      2956                 莱茵春天小区
# 24         宝坻3路       0          12       208                  宝坻火车站
# 25         宝坻3路       1          12      5096                   西孟庄村
# 26         722路       0          23      1675                华润万家北辰店
# 27    722路(徐堡线)       0          27      1675                华润万家北辰店
# 28    722路(徐堡线)       1          27      1719                    后堡村
# 29         844路       0          39      2495                 金海湖公交站
# ...         ...     ...         ...       ...                    ...
# 1409       126路       0          11      5068               西区新安路公交站
# 1410    通勤快车15路       0           6      3632          荣居园(双青新家园公交站)
# 1411    通勤快车15路       1           6      5128                 西横堤地铁站
# 1412   590路(停运)       0          11      2154                  九园石材城
# 1413   590路(停运)       1          11      2545                   锦绣香江
# 1414   954路(区间)       0          14      2866           渌水道站(渌水道公交站)
# 1415   954路(区间)       1          14      2866           渌水道站(渌水道公交站)
# 1416       312路       0          25      4186                   天津南站
# 1417       312路       1          25      4186                   天津南站
# 1418       893路       0           5      4053  健康产业园公交总站(天津健康产业园公交站)
# 1419       893路       1           5      2208                  健康产业园
# 1420       314路       0          10      2307                 景瑞阳光尚城
# 1421       314路       1          10       NaN                    NaN
# 1422     静海免费专线       0           6      2563                   静海商场
# 1423     静海免费专线       1           5      4959                   新湖广场
# 1424       476路       0           5      3357                  潘庄规划馆
# 1425       476路       1           5      5095                    西孙庄
# 1426       187路       0           2      4379                  通莎客运站
# 1427       187路       1           2      2420                  蓟州客运站
# 1428       188路       0           2      4226           天津站(天津站A2站台)
# 1429       188路       1           2      2420                  蓟州客运站
# 1430   897路(支线)       0           3      2576             静雅园(子牙公交站)
# 1431       225路       0          10      3215               南开大学新址西门
# 1432       225路       1          10      3215               南开大学新址西门
# 1433   732路(支线)       0           8      3632          荣居园(双青新家园公交站)
# 1434   732路(支线)       1           8      5128                 西横堤地铁站
# 1435   612路(快线)       0           6      4129               天南大新址公交站
# 1436   612路(快线)       1           6      3210                   南开大学
# 1437   615路(快线)       0           5      4129               天南大新址公交站
# 1438   615路(快线)       1           5      4198                   天津大学
#
#      station_1        name_1 station_2              name_2 station_3   ...     \
# 0         3412          前槐树庄      5582                裕和家园         0   ...
# 1         2119           黄庄乡      4582                 王木庄      5912   ...
# 2         3474          汽车市场         0               247社区      5582   ...
# 3          193          宝坻五中       201              宝坻巡警支队      2446   ...
# 4         2450          金侨大道         1               奥克斯电气      3370   ...
# 5         3557          人民法庭      4497                武宁路口      4863   ...
# 6         5285           云丽园      2080                 贺兰路      3010   ...
# 7         3267           宁乐里      1765          天塔南(原环湖医院)       806   ...
# 8          773           东盈里      4880               新东方家园      3498   ...
# 9         3500        秋丽家园北门      3499                秋丽家园      1115   ...
# 10         458           春江里       819                 丹江里      6033   ...
# 11        5828           制药厂         2                 奥兰里       464   ...
# 12        4413        万科金域蓝湾       NaN                 NaN      4342   ...
# 13         980         大港学苑路       288              滨海学院东门      1314   ...
# 14         NaN           NaN      4413              万科金域蓝湾      4322   ...
# 15        2879           炼油厂       991              大港石化公司      1186   ...
# 16        5957          浙商大厦       285              滨海国泰大厦        15   ...
# 17        2879           炼油厂       991              大港石化公司      1186   ...
# 18        4992         校区商业街      4223  天津科技大学[天津科技大学泰达校区]      2705   ...
# 19        5176          西部新城      2435                 觉顺园      4422   ...
# 20        2100   鸿正绿色家园(福州道)         4                奥林花园      2955   ...
# 21         341        石油新村五区      2972                蓝苑小区      3966   ...
# 22        4950    新港三号路(海安里)      1961                 海西路      4956   ...
# 23         284          滨海名都         4                奥林花园       926   ...
# 24           5           安乐村      2138                黄辛庄村      2596   ...
# 25         708          东孟庄村      3029                龙虎庄村      2043   ...
# 26        3138            马庄        85                北仓礼堂        84   ...
# 27        3138            马庄        85                北仓礼堂        84   ...
# 28        4858           徐堡村      2085                 郝堡村      3404   ...
# 29        2494           金海湖      1420              国际企业大道       385   ...
# ...        ...           ...       ...                 ...       ...   ...
# 1409      5069           江泰路      2049                航天公寓      5737   ...
# 1410      3782         双青新家园      2092               韩家墅市场      3020   ...
# 1411      3605          瑞景中学      3020                 龙洲道      2092   ...
# 1412      4018           隋家庄      2156               九园管委会      2151   ...
# 1413      4350          甜水井村      4036                首航节能      2150   ...
# 1414      3059        梅林路浯水道      5378                 怡林园      4532   ...
# 1415      3059        梅林路浯水道      2484                 金江里      2727   ...
# 1416      3976         社会山中心      3978               社会山花园      3977   ...
# 1417      3976         社会山中心      2235                君悦花苑      5939   ...
# 1418      4290          昆明湖路      5854          天津中医药大学新校区      4182   ...
# 1419      4182     天津体育学院新校区      5854          天津中医药大学新校区      4290   ...
# 1420      6027            赵庄      6029                 赵庄南      2746   ...
# 1421      4581          王朝酒厂      5293                云鼎花园      5033   ...
# 1422      5235         静海新华里      2330                江海陶瓷      5174   ...
# 1423      2565         静海地税局      5174                 西边庄      2330   ...
# 1424      3359         潘庄镇政府      3356                 潘庄桥      2392   ...
# 1425      2392           纪庄子      3356                 潘庄桥      3359   ...
# 1426      2420         蓟州客运站       NaN                 NaN       NaN   ...
# 1427      4379         通莎客运站       NaN                 NaN       NaN   ...
# 1428      2420         蓟州客运站       NaN                 NaN       NaN   ...
# 1429      4226  天津站(天津站A2站台)       NaN                 NaN       NaN   ...
# 1430      2577           静馨园      4844            小黄庄[静海区]       NaN   ...
# 1431      3143           马蹄湖      3221            南开大学第二食堂      2859   ...
# 1432      3211      南开大学专家公寓      3220            南开大学第一食堂      3212   ...
# 1433      3636           荣溪园      3608                瑞景时代      3947   ...
# 1434      3605          瑞景中学      3020                 龙洲道      3633   ...
# 1435      3218      南开大学新校西门      4201            天津大学新校东门      4138   ...
# 1436      3870           手表厂      4138                  天塔      4201   ...
# 1437      4201      天津大学新校东门      4138                  天塔      3383   ...
# 1438      3383           七里台      4138                  天塔      4201   ...
#
#      station_122 name_122 station_123 name_123 station_124 name_124  \
# 0           None     None        None     None        None     None
# 1           None     None        None     None        None     None
# 2           None     None        None     None        None     None
# 3           None     None        None     None        None     None
# 4           None     None        None     None        None     None
# 5           None     None        None     None        None     None
# 6           None     None        None     None        None     None
# 7           None     None        None     None        None     None
# 8           None     None        None     None        None     None
# 9           None     None        None     None        None     None
# 10          None     None        None     None        None     None
# 11          None     None        None     None        None     None
# 12          None     None        None     None        None     None
# 13          None     None        None     None        None     None
# 14          None     None        None     None        None     None
# 15          None     None        None     None        None     None
# 16          None     None        None     None        None     None
# 17          None     None        None     None        None     None
# 18          None     None        None     None        None     None
# 19          None     None        None     None        None     None
# 20          None     None        None     None        None     None
# 21          None     None        None     None        None     None
# 22          None     None        None     None        None     None
# 23          None     None        None     None        None     None
# 24          None     None        None     None        None     None
# 25          None     None        None     None        None     None
# 26          None     None        None     None        None     None
# 27          None     None        None     None        None     None
# 28          None     None        None     None        None     None
# 29          None     None        None     None        None     None
# ...          ...      ...         ...      ...         ...      ...
# 1409         NaN      NaN         NaN      NaN         NaN      NaN
# 1410         NaN      NaN         NaN      NaN         NaN      NaN
# 1411         NaN      NaN         NaN      NaN         NaN      NaN
# 1412         NaN      NaN         NaN      NaN         NaN      NaN
# 1413         NaN      NaN         NaN      NaN         NaN      NaN
# 1414         NaN      NaN         NaN      NaN         NaN      NaN
# 1415         NaN      NaN         NaN      NaN         NaN      NaN
# 1416         NaN      NaN         NaN      NaN         NaN      NaN
# 1417         NaN      NaN         NaN      NaN         NaN      NaN
# 1418         NaN      NaN         NaN      NaN         NaN      NaN
# 1419         NaN      NaN         NaN      NaN         NaN      NaN
# 1420         NaN      NaN         NaN      NaN         NaN      NaN
# 1421         NaN      NaN         NaN      NaN         NaN      NaN
# 1422         NaN      NaN         NaN      NaN         NaN      NaN
# 1423         NaN      NaN         NaN      NaN         NaN      NaN
# 1424         NaN      NaN         NaN      NaN         NaN      NaN
# 1425         NaN      NaN         NaN      NaN         NaN      NaN
# 1426         NaN      NaN         NaN      NaN         NaN      NaN
# 1427         NaN      NaN         NaN      NaN         NaN      NaN
# 1428         NaN      NaN         NaN      NaN         NaN      NaN
# 1429         NaN      NaN         NaN      NaN         NaN      NaN
# 1430         NaN      NaN         NaN      NaN         NaN      NaN
# 1431         NaN      NaN         NaN      NaN         NaN      NaN
# 1432         NaN      NaN         NaN      NaN         NaN      NaN
# 1433         NaN      NaN         NaN      NaN         NaN      NaN
# 1434         NaN      NaN         NaN      NaN         NaN      NaN
# 1435         NaN      NaN         NaN      NaN         NaN      NaN
# 1436         NaN      NaN         NaN      NaN         NaN      NaN
# 1437         NaN      NaN         NaN      NaN         NaN      NaN
# 1438         NaN      NaN         NaN      NaN         NaN      NaN
#
#      station_125 name_125 station_126 name_126
# 0           None     None        None     None
# 1           None     None        None     None
# 2           None     None        None     None
# 3           None     None        None     None
# 4           None     None        None     None
# 5           None     None        None     None
# 6           None     None        None     None
# 7           None     None        None     None
# 8           None     None        None     None
# 9           None     None        None     None
# 10          None     None        None     None
# 11          None     None        None     None
# 12          None     None        None     None
# 13          None     None        None     None
# 14          None     None        None     None
# 15          None     None        None     None
# 16          None     None        None     None
# 17          None     None        None     None
# 18          None     None        None     None
# 19          None     None        None     None
# 20          None     None        None     None
# 21          None     None        None     None
# 22          None     None        None     None
# 23          None     None        None     None
# 24          None     None        None     None
# 25          None     None        None     None
# 26          None     None        None     None
# 27          None     None        None     None
# 28          None     None        None     None
# 29          None     None        None     None
# ...          ...      ...         ...      ...
# 1409         NaN      NaN         NaN      NaN
# 1410         NaN      NaN         NaN      NaN
# 1411         NaN      NaN         NaN      NaN
# 1412         NaN      NaN         NaN      NaN
# 1413         NaN      NaN         NaN      NaN
# 1414         NaN      NaN         NaN      NaN
# 1415         NaN      NaN         NaN      NaN
# 1416         NaN      NaN         NaN      NaN
# 1417         NaN      NaN         NaN      NaN
# 1418         NaN      NaN         NaN      NaN
# 1419         NaN      NaN         NaN      NaN
# 1420         NaN      NaN         NaN      NaN
# 1421         NaN      NaN         NaN      NaN
# 1422         NaN      NaN         NaN      NaN
# 1423         NaN      NaN         NaN      NaN
# 1424         NaN      NaN         NaN      NaN
# 1425         NaN      NaN         NaN      NaN
# 1426         NaN      NaN         NaN      NaN
# 1427         NaN      NaN         NaN      NaN
# 1428         NaN      NaN         NaN      NaN
# 1429         NaN      NaN         NaN      NaN
# 1430         NaN      NaN         NaN      NaN
# 1431         NaN      NaN         NaN      NaN
# 1432         NaN      NaN         NaN      NaN
# 1433         NaN      NaN         NaN      NaN
# 1434         NaN      NaN         NaN      NaN
# 1435         NaN      NaN         NaN      NaN
# 1436         NaN      NaN         NaN      NaN
# 1437         NaN      NaN         NaN      NaN
# 1438         NaN      NaN         NaN      NaN
#
# [1439 rows x 257 columns]

# %%
aaa = Network_list.copy()
aaa = aaa.sort_values(by=['line_no','line_up'])
aaa.to_csv('Network_byorder.csv', index=False)

# %%
Se.to_csv('station_dict.csv')
Network_list.to_csv('Network_bus.csv', index=False)
